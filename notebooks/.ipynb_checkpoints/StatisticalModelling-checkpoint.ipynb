# %% [markdown]
# # Basics of Modelling

# %% [markdown]
# # Independent Data Modelling

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# # Dependent Data Modelling

# %% [markdown]
# ## Multilevel Models

# %% [markdown]
# ## Marginal Models

# %% [markdown]
# # Bayesian Modelling
